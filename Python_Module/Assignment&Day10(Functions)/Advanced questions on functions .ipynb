# %%
# Advanced questions on functions ( 5+)

Q1 Write a function in Python to check duplicate letters inside a word, without considering case. It must accept a string, i.e., a sentence. The function should return True if the sentence has any word with duplicate letters, else return False. 

Example:
input: 
i am glad to be here!
output True (because here word has duplicate letters)

input:
you are wonderful
output False (because no word has duplicate letters)


Q2 Write a function in Python to parse a string such that it accepts a parameter- an encoded string. This encoded string will contain a first name, last name, and an id. You can separate the values in the string by any number of zeros. The id will not contain any zeros. The function should return a Python dictionary with the first name, last name, and id values. For example, if the input would be "John000Doe000123". Then the function should return: { "first_name": "John", "last_name": "Doe", "id": "123" }

Q3 Write a function in Python to convert a decimal to a hex. It must accept a string of ASCII characters as input. The function should return the value of each character as a hexadecimal string. You have to remove the suffix 0x from all hex representations. You have to separate each byte by a space and return all alpha hexadecimal characters as lowercase.

Ex. input 'AB'
Output '41 42'
Explaination : hex value for 'A' is 0x41 and 'B' is 0x42. So take only 41 and 42 removing the prefix '0x' .

input '@21Z'
Output '40 32 31 5a'


Q4 Compress the given string S using following rules, 
- If the string contains a alphabate or special char, that occurs 4 times consecutively, then replace it with its compressed representation, (4, given character) in the string. 
- Neglect the case of latters when counting the repeatitions and creating compressed representation. 
- If there are multiple spaces then take them as a single space only, and replace with (1, ).
- S is containing only aphabates or special characters, anything other than this should be kept as it is in the output

Ex. 
input 'aabbbbeeeaa'
output '(2,a)(4,b)(3,e)(2,a)'

input 'Aa jj  '
output '(2,a)(1, )(2,j)(1, )'


Q5 Write a function named 'format_number' that takes a number as its only parameter. Your function should convert the number to a string and add commas as a thousand separators. For example, calling format_number(1000000) should return "1,000,000". 
- In case negetive number then print error message

Q6 There is pizza shop. When order is given it takes name of the person as input. There can be typo mistakes, so system allows to edit the name. Write a function which takes a name string as input, position, and new character. Then it changes character in name for given position with new character. Return the edited string from the function.

Ex. 
input "SAW",2,"M"
output "SAM"

input "ABC", 0, "Z"
output "ZBC"


Q7 Ms. Gabriel Williams is a botany professor at District College. One day, she asked her student Mickey to compute the average of all the plants with distinct heights in her greenhouse.

Formula used:
Average = Sum of Distinct Heights/Total Number of Distinct Heights

Function Description
The average has the following parameters:
    Input string containing all heights seperated by space
Returns
    float: the resulting float value rounded to 3 places after the decimal

Input Format
The first line contains the integer, N, the size or arr.
The second line contains the N space-separated integers, arr[i].
Constraints

0 < N <= 100
Sample Input
STDIN                                       Function
-----                                       --------
10                                          arr[] size N = 10
161 182 161 154 176 170 167 171 170 174     arr = [161, 181, ..., 174]

Sample Output
169.375

Explanation
Here, 154 161 167 170 171 174 176 182 are distinct values from input.
So, 
Average = 1355/8 = 169.375


Q8 There is an array of n integers. There are also 2 disjoint sets, A and B, each containing m integers. You like all the integers in set A and dislike all the integers in set B. Your initial happiness is 0. For each i integer in the array, if i belongs to A, you add 1 to your happiness. If i belongs to B, you add -1 to your happiness. Otherwise, your happiness does not change. Output your final happiness at the end.

Note: Since A and B are sets, they have no repeated elements. However, the array might contain duplicate elements.
Constraints
    1 <= n <= 105
    1 <= m <= 105
    1 <= Any integer in the input <= 109

Input Format
The first line contains integers n and m separated by a space.
The second line contains n integers, the elements of the array.
The third and fourth lines contain m integers, A and B, respectively.

Output Format
Output a single integer, your total happiness.

Sample Input
3 2
1 5 3
3 1
5 7

Sample Output
1


Q9 There is an essay writting competition. Winner will be a person who uses maximum number of unique valid words in his/her essay. There is a bonus score if essay has numbers in it. Take 5 essays as input from user. Print the winner essay number using following function.

The function takes input a string containing an essay and returns the total score.
- There are multiple sentences in one essay.
- After every word there is a space
- Sentence can end with 3 characters --> .?!
- A valid word contains minimum 2 characters
- All other special characters should be neglected
- Bonus score to each whole number is 1

Example:
input 5 essays
abc dfg
a b g h 123 12 
asd fgh hjk tyu klu rty 333 23
1 2 34 you are good!
this is sample. take more inputs.

output: 3

Explaination: 
first essay score is 2 because of 2 distinct valid words and 0 whole numbers
Second essay score is 2 because of 0 distinct valid words and 2 whole numbers
Third essay score is 8 because of 6 distinct valid words and 2 whole numbers
Fourth essay score is 6 because of 3 distinct valid words and 3 whole numbers
Fifth essay score is 6 because of 6 distinct valid words and 0 whole numbers
So 3 is winner



Super Advanced Practice (10 +)

Q. There is company which maintains emloyee records in a python list containing dictionaries.  Write a function that takes this list of dictionaries as input. Dictionary has name, age and gender of a person. Sort all entries by age. If there is a tie then sort by gender. If still there is tie then sort by name. In names capital letters are considered as higher than lower case letters.
In case of negative age, special characters in name, or gender other than 'M' or 'F' give appropriate error message and don't include the record in the output list.

Format of dictionary {'name':'emp_name','age':'emp_age','geder':'emp_gender'}

Ex. 
input: 
[ {'name':'ss','age':'23','geder':'F'},
{'name':'xy','age':'19','geder':'F'},
{'name':'abc','age':'23','geder':'F'},
{'name':'iam','age':'23','geder':'M'},
{'name':'aa','age':'45','geder':'M'},
]

Output :
[ {'name':'xy','age':'19','geder':'F'},
{'name':'abc','age':'23','geder':'F'},
{'name':'ss','age':'23','geder':'F'},
{'name':'iam','age':'23','geder':'M'},
{'name':'aa','age':'45','geder':'M'},
]


Q Mr. Vincent works in a door mat manufacturing company. One day, he designed a new door mat with the following specifications:

Mat size must be N X M. (N is an odd natural number, and M is 3 times N.)
The design should have ‘WELCOME’ written in the center.
The design pattern should only use |, . and – characters.

Sample Designs
Size: 7 x 21 
    ---------.|.---------
    ------.|..|..|.------
    ---.|..|..|..|..|.---
    -------WELCOME-------
    ---.|..|..|..|..|.---
    ------.|..|..|.------
    ---------.|.---------
    
    Size: 11 x 33
    ---------------.|.---------------
    ------------.|..|..|.------------
    ---------.|..|..|..|..|.---------
    ------.|..|..|..|..|..|..|.------
    ---.|..|..|..|..|..|..|..|..|.---
    -------------WELCOME-------------
    ---.|..|..|..|..|..|..|..|..|.---
    ------.|..|..|..|..|..|..|.------
    ---------.|..|..|..|..|.---------
    ------------.|..|..|.------------
    ---------------.|.---------------

Input Format
A single line containing the space-separated values of N and M.

Constraints
    5 < N < 101
    15 < M < 303

Output Format
Output the design pattern.

Sample Input
9 27

Sample Output

------------.|.------------
---------.|..|..|.---------
------.|..|..|..|..|.------
---.|..|..|..|..|..|..|.---
----------WELCOME----------
---.|..|..|..|..|..|..|.---
------.|..|..|..|..|.------
---------.|..|..|.---------
------------.|.------------


Q There is an airport which maintains data of passengers coming in list of entries. Each entry is a string of format "name:TicketID". TicketId is of 5 characters. TicketID contains first two letters as airline code and last 3 letters as seat number.
Also, there is another list of airline data. Here each entry is a string of format "AirlineCode:Capacity". 
Write a function which takes these two lists as input 
Function returns list of airline codes which are not full

Example
input:
[ "Simba:AA003", "Prayas:DA006", "Pran:DA023", "Rama:AA001", "Abhay:SJ098"]
[ "AA:02", "DA:04", "SJ:100"]

Output:
[DA, SJ ]
